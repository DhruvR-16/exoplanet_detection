# %% [markdown]
# # Exoplanet Detection - Visualization Dashboard
#
# This notebook contains visualization tools for analyzing predictions from the exoplanet detection pipeline.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# %%
def load_predictions(filename='predictions.csv'):
    """Load predictions from CSV file"""
    if not Path(filename).exists():
        print(f"Error: {filename} not found")
        return None
    
    df = pd.read_csv(filename)
    print(f"Loaded {len(df)} predictions from {filename}")
    return df

# %%
def visualize_predictions(filename='predictions.csv', save_path='visualization/predictions_visualization.png'):
    """Create comprehensive visualization of predictions dashboard"""
    df = load_predictions(filename)
    if df is None or df.empty:
        print("No data available to visualize.")
        return
    
    # Create the output directory if it doesn't already exist
    Path(save_path).parent.mkdir(parents=True, exist_ok=True)
    
    # Set up a 2x2 grid of plots for the dashboard
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    fig.suptitle('Exoplanet Detection Analysis Dashboard', fontsize=16, fontweight='bold')
    
    # Top-Left: Histogram of planet probabilities
    ax1 = axes[0, 0]
    if 'planet_probability' in df.columns:
        ax1.hist(df['planet_probability'].dropna(), bins=20, color='steelblue', edgecolor='black', alpha=0.7)
        ax1.axvline(0.5, color='red', linestyle='--', linewidth=2, label='Decision Threshold')
        ax1.set_xlabel('Planet Probability', fontsize=12)
        ax1.set_ylabel('Frequency', fontsize=12)
        ax1.set_title('Distribution of Planet Probabilities', fontsize=14, fontweight='bold')
        ax1.legend()
        ax1.grid(alpha=0.3)
    else:
        ax1.text(0.5, 0.5, 'planet_probability column not found', ha='center', va='center')
    
    # Top-Right: Pie chart of planet vs non-planet classifications
    ax2 = axes[0, 1]
    if 'prediction' in df.columns:
        prediction_counts = df['prediction'].value_counts()
        colors = ['#2ecc71' if p == 'Planet' else '#e74c3c' for p in prediction_counts.index]
        ax2.pie(prediction_counts.values, labels=prediction_counts.index, autopct='%1.1f%%',
                startangle=90, colors=colors, textprops={'fontsize': 12, 'fontweight': 'bold'})
        ax2.set_title('Planet vs Non-Planet Classifications', fontsize=14, fontweight='bold')
    else:
        ax2.text(0.5, 0.5, 'prediction column not found', ha='center', va='center')
    
    # Bottom-Left: Scatter plot of Period vs Transit Depth
    ax3 = axes[1, 0]
    if 'prediction' in df.columns and 'period_days' in df.columns and 'depth' in df.columns:
        planet_mask = df['prediction'] == 'Planet'
        ax3.scatter(df[planet_mask]['period_days'], df[planet_mask]['depth'], 
                    c='green', s=100, alpha=0.6, label='Planet', marker='o')
        ax3.scatter(df[~planet_mask]['period_days'], df[~planet_mask]['depth'], 
                    c='red', s=100, alpha=0.6, label='Non-Planet', marker='x')
        ax3.set_xlabel('Orbital Period (days)', fontsize=12)
        ax3.set_ylabel('Transit Depth', fontsize=12)
        ax3.set_title('Period vs Transit Depth', fontsize=14, fontweight='bold')
        ax3.legend()
        ax3.grid(alpha=0.3)
        ax3.set_xscale('log')
    else:
        ax3.text(0.5, 0.5, 'Required columns missing for Period vs Depth', ha='center', va='center')
    
    # Bottom-Right: Scatter plot of Signal-to-Noise Ratio vs Transit Duration
    ax4 = axes[1, 1]
    if 'prediction' in df.columns and 'snr' in df.columns and 'duration_days' in df.columns:
        # Multiply duration_days by 24 to convert into hours
        ax4.scatter(df[planet_mask]['snr'], df[planet_mask]['duration_days'] * 24, 
                    c='green', s=100, alpha=0.6, label='Planet', marker='o')
        ax4.scatter(df[~planet_mask]['snr'], df[~planet_mask]['duration_days'] * 24, 
                    c='red', s=100, alpha=0.6, label='Non-Planet', marker='x')
        ax4.axvline(7.0, color='orange', linestyle='--', linewidth=2, label='SDE/SNR Threshold')
        ax4.set_xlabel('Signal-to-Noise Ratio (SNR)', fontsize=12)
        ax4.set_ylabel('Transit Duration (hours)', fontsize=12)
        ax4.set_title('SNR vs Transit Duration', fontsize=14, fontweight='bold')
        ax4.legend()
        ax4.grid(alpha=0.3)
    else:
        ax4.text(0.5, 0.5, 'Required columns missing for SNR vs Duration', ha='center', va='center')
    
    # Adjust layout to prevent overlap and save the dashboard image
    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    print(f"✓ Visualization saved to {save_path}")
    plt.show()

# %%
def feature_correlation_heatmap(filename='predictions.csv', save_path='visualization/feature_correlation.png'):
    """Create correlation heatmap of numerical features"""
    df = load_predictions(filename)
    if df is None or df.empty:
        return
    
    # Ensure the save directory exists
    Path(save_path).parent.mkdir(parents=True, exist_ok=True)
    
    # Filter for numeric columns to compute correlations securely
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    feature_cols = [col for col in numeric_cols if col not in ['timestamp']]
    
    if len(feature_cols) < 2:
        print("Not enough numeric features found for correlation")
        return
    
    # Calculate the Pearson correlation matrix
    corr_matrix = df[feature_cols].corr()
    
    # Setup the heatmap figure
    plt.figure(figsize=(12, 10))
    plt.imshow(corr_matrix, cmap='coolwarm', aspect='auto', vmin=-1, vmax=1)
    plt.colorbar(label='Correlation Coefficient')
    
    # Align ticks with feature names
    plt.xticks(range(len(feature_cols)), feature_cols, rotation=45, ha='right')
    plt.yticks(range(len(feature_cols)), feature_cols)
    plt.title('Feature Correlation Heatmap', fontsize=16, fontweight='bold', pad=20)
    
    # Overlay the textual correlation values on each cell
    for i in range(len(feature_cols)):
        for j in range(len(feature_cols)):
            # Handle potential NaN values resulting from columns with constant values
            val = corr_matrix.iloc[i, j]
            if not pd.isna(val):
                plt.text(j, i, f'{val:.2f}', ha='center', va='center', fontsize=8)
    
    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    print(f"✓ Correlation heatmap saved to {save_path}")
    plt.show()

# %%
def summary_statistics(filename='predictions.csv'):
    """Print overall summary statistics of predictions"""
    df = load_predictions(filename)
    if df is None or df.empty:
        print("No data available to summarize.")
        return
    
    print("\n" + "="*60)
    print("PREDICTION SUMMARY STATISTICS")
    print("="*60)
    
    # Calculate and output total instances
    print(f"\nTotal records processed: {len(df)}")
    
    # Show classification targets
    if 'prediction' in df.columns:
        print(f"Planets detected: {(df['prediction'] == 'Planet').sum()}")
        print(f"Non-planets: {(df['prediction'] == 'Non-Planet').sum()}")
    
    # Descriptive statistics for planet probability
    if 'planet_probability' in df.columns:
        print("\nPlanet Probability Stats:")
        print(f"  Mean: {df['planet_probability'].mean():.3f}")
        print(f"  Median: {df['planet_probability'].median():.3f}")
        print(f"  Std Dev: {df['planet_probability'].std():.3f}")
    
    # Orbital period context
    if 'period_days' in df.columns:
        print("\nOrbital Period Stats (days):")
        print(f"  Mean: {df['period_days'].mean():.2f}")
        print(f"  Median: {df['period_days'].median():.2f}")
        print(f"  Range: {df['period_days'].min():.2f} - {df['period_days'].max():.2f}")
    
    # Signal-to-Noise summary
    if 'snr' in df.columns:
        print("\nSNR Stats:")
        print(f"  Mean: {df['snr'].mean():.2f}")
        print(f"  Median: {df['snr'].median():.2f}")
        print(f"  Above threshold (≥7): {(df['snr'] >= 7).sum()} / {len(df)}")
    
    print("\n" + "="*60)

# %% [markdown]
# ## Usage Examples

# %%
# Create main visualization dashboard
visualize_predictions('predictions.csv')

# %%
# Show correlation heatmap
feature_correlation_heatmap('predictions.csv')

# %%
# Print summary statistics
summary_statistics('predictions.csv')
